# %%
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL
import credentials # Import api/access_token keys from credentials.py
import settings # Import related setting constants from settings.py 

import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob
# Streaming With Tweepy 
# http://docs.tweepy.org/en/v3.4.0/streaming_how_to.html#streaming-with-tweepy


# Override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):
    '''
    Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
    https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
    '''
    
    def on_status(self, status):
        '''
        Extract info from tweets
        '''
        
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        sentiment = TextBlob(text).sentiment
        polarity = sentiment.polarity
        subjectivity = sentiment.subjectivity
        
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if mydb.is_connected():
            mycursor = mydb.cursor()
            sql = "INSERT INTO {} (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, \
                user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
            mycursor.execute(sql, val)
            mydb.commit()
            mycursor.close()
    
    
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, stop srcraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
def clean_tweet(self, tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="1devansh",
    database="TwitterDB",
    port=3306
    
)
if mydb.is_connected():
    '''
    Check if this table exits. If not, then create a new one.
    '''
    mycursor = mydb.cursor()
    mycursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(settings.TABLE_NAME))
    if mycursor.fetchone()[0] != 1:
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
        mydb.commit()
    mycursor.close()

# %%
auth  = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOEKN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
# Close the MySQL connection as it finished
# However, this won't be reached as the stream listener won't stop automatically
# Press STOP button to finish the process.
mydb.close()
# Out:
# tyRichel: This coming from a guy who, after 3 weeks; still hasn't fixed the profile pic of his crooked face mask! Speaking of things…
# Long: None, Lati: None
# RT @KSUC: "Surat keterangan bebas covid-19" is basically nonsense when you can get infected at any time after you owned the letter anyway
# Long: None, Lati: None
# RT @War_Kittens: I... Never thought I'd see the day a public health org would suggest glory holes to combat an epidemic. This is definitely…
# Long: None, Lati: None
# @RepAndyBiggsAZ Currently 1,985,348 Infections in the US.
# 111,979 Americans have perished due to Covid-19
# https://t.co/C3c4jcRilh
# Long: None, Lati: None
# Work sweet work
# Long: None, Lati: None
# RT @Stochastic_walk: It needed a Pandemic to bring health sector reforms in public discourse in India. What will it take for restructuring…
# Long: None, Lati: None
# RT @UR_Ninja: Today we exposed Ohio National Guard soldier Shandon Simpson, deployed to DC protests, as a neo-nazi who reportedly tested po…
# Long: None, Lati: None
# RT @AxiomCatwalk: Have you heard the joke about getting rid of COVID??
#
# It's a riot!😂
# Long: None, Lati: None
# RT @Sid_Seixeiro: We've reached the point in this pandemic where public officials are seriously asking people not to flush used masks, glov…
# Long: None, Lati: None
# @kiwibardy Queenstown area hasn't recorded a new coronavirus case in 54 days! Ski season finishes at the end of Sep… https://t.co/9ahkpYXoy0
# Long: None, Lati: None
# RT @DrDenaGrayson: The only “immunity” to #coronavirus that I see is a callous indifference to growing number of Americans dying each day.🤬…
# Long: None, Lati: None
# RT @Oprah: .@staceyabrams addresses how the confluence of events, including the COVID-19 pandemic, have led to the awakening in this moment…
# Long: None, Lati: None
# RT @JoeBiden: Because of Donald Trump's negligence and incompetence:
#
# - More than 110,000 people have died
# - We have nearly 2 million case…
# Long: None, Lati: None
# RT @AlexBerenson: And finally #COVID deaths. These lag, so don’t put too much stock in them, but again the (non)-trend is hard to argue. Bu…
# Long: None, Lati: None
# RT @SBCUlater: Wait has anybody tried leading the coronavirus down the romans road?
# Long: None, Lati: None
# RT @MBChinoLeyco: Coronavirus takes a heavier toll on PH economy than its ASEAN neighbors due to gov's reliance on lockdowns instead of ear…
# Long: None, Lati: None
# RT @clarise__rivera: If you didn’t know, Napa is planning on implementing a $128mil jail amid our BLM movement, budget cuts on education (r…
# Long: None, Lati: None
# RT @RonBrownstein: “I have never seen the scale of election failures happening in Georgia today,” McDonald said. “This does not bode well f…
# Long: None, Lati: None
# RT @depressionnote: it’s okay if you thought the pandemic would have given you lots of time to be productive and then you ended up doing no…
# Long: None, Lati: None
# RT @WizBish: #JohnsonHasFailed
# #ToriesHaveFailed
#
# We will all fail if we don’t withdraw consent to be misgoverned so lethally.
#
# #ToriesOut
# Long: None, Lati: None
# RT @wtp__2020: Trump’s FAV disaster management party games:
#
# • Redraw The Hurricane Map
# • PR Paper Towel Toss
# • Rake The Forest Floor
# •…
# Long: None, Lati: None
# @SueFritz13 Sue never think we don't want you. We do it's just that we're scared of the Covid 19. Our own people ar… https://t.co/mveMBajMp3
# Long: None, Lati: None
# RT @Timodc: I know we have all got bored with it but 6,000 people have died from COVID already in June. This is more than the total U.S. de…
# Long: None, Lati: None
# RT @leftcoastbabe: New IHME projected COVID-19 deaths by Aug 4.  145,000.
# I missed the Trump tweet taking credit.
# Long: None, Lati: None
# RT @ochocinco: Only thing fucking me has been this pandemic 😢 https://t.co/YDQ1b0CWvW
# Long: None, Lati: None
# RT @selectedwisdom: The Georgia voting situation today does not bode well for election night in November- we’ve got COVID, protests, politi…
# Long: None, Lati: None
# RT @nandtara: Yes @navikakumar stay on track with the evil fascist script. Feed our starving, pandemic stricken Indian citizens on the opiu…
# Long: None, Lati: None
# RT @cctv_idiots: Hologram to stop the spread of Covid in China 🇨🇳 https://t.co/KRJWbUJyh8
# Long: None, Lati: None
# RT @skaijackson: Donald Trump called the coronavirus the “Chinese virus” and called black people “thugs” but y’all still think he’s not rac…
# Long: None, Lati: None
# RT @insan_nls1437: When entire nation was in Lockdown due to COVID-19, 2000 @derasachasauda volunteers with #SpiritToServeHumanity invested…
# Long: None, Lati: None
# Texas Hospitalizations Surge To Record High As Dr. Fauci Warns Pandemic “Far From Over”: Live Updates
#
# Summary:
#
# Te… https://t.co/VmS98WU83s
# Long: None, Lati: None
# RT @zeynep: The incubation period for the COVID positive hairstylists in Missouri just ended. The two stylists and 140+ clients all wore ma…
# Long: None, Lati: None
# RT @sandela: Hey @justintrudeau, you know what's better (and likely cheaper overall) than criminalizing people, arresting them, &amp; incarcera…
# Long: None, Lati: None
# @GavinNewsom Why are you silent on recommending protestors getting tested for covid 19?? @NYGovCuomo is setting up… https://t.co/ACj0FTFQKQ
# Long: None, Lati: None
# RT @AynRandPaulRyan: “In a period of four months, it has devastated the whole world, and it isn’t over yet. Covid-19 is the disease Fauci a…
# Long: None, Lati: None
# RT @AxiomCatwalk: Have you heard the joke about getting rid of COVID??
#
# It's a riot!😂
# Long: None, Lati: None
# RT @anches: @DoYouEvenLif Meanwhile there’s no peace in the Middle East, the coronavirus pandemic still rages out of control, and, well, im…
# Long: None, Lati: None
# RT @JoeBiden: Because of Donald Trump's negligence and incompetence:
#
# - More than 110,000 people have died
# - We have nearly 2 million case…
# Long: None, Lati: None
# RT @DoYouEvenLif: Jared Kushner went from the trying to “make peace”in the Middle East, to “being in” the Coronavirus Task Force, to Police…
# Long: None, Lati: None
# RT @Oprah: .@RevDrBarber explains how all the Black lives lost to COVID-19 and George Floyd’s death have led to this collective worldwide g…
# Long: None, Lati: None
# RT @JamesHasson20: This is so infuriating.
#
# Birx said 70 urban coronavirus testing centers were destroyed in the riots, “which had already…
# Long: None, Lati: None
# RT @Walldo: NEW: The head of CrossFit told staff on a Zoom call "we are not in mourning for Georg Floyd."
#
# He also shared conspiracy theor…
# Long: None, Lati: None
# RT @TheRealPBarry: Hey #chriskenny since you claim to be interested in facts ... 'Three big studies dim hopes that hydroxychloroquine can t…
# Long: None, Lati: None
# RT @canyonmoonblu: girls don’t want boyfriends or girlfriends they just want Coronavirus to get its shit together so they can see Harry Sty…
# Long: None, Lati: None
# RT @stillgray: Reddit was a nice respite from Twitter during the COVID crisis but it's all gone to hell with virtue signaling and anti-poli…
# Long: None, Lati: None
# RT @CalebJHull: Here's Chris Cuomo blaming the recent rise in coronavirus on states re-opening without mentioning the mass protests a singl…
# Long: None, Lati: None
# RT @gholland04: !!New Q-Drop 4444
#
# Title:
# Will D's Push 2nd COVID-19 Wave Due to Protests/Riots to Keep the "Mail-in Voting" Narrative Goin…
# Long: None, Lati: None
# RT @NYCDEATHROWCATS: Tiger was brought in with his two housemates and may have been exposed to covid-19. He is nervous and sad. Tiger needs…
# Long: None, Lati: None
# RT @AndrewDonovan: Happening Tomorrow: @SyracuseSchools Board of Education will vote to extend Superintendent Jaime Alicea’s contract throu…
# Long: None, Lati: None
# RT @greg_garrison: Birmingham Schools end lease with Church of the Highlands, which paid $288,000 a year to City Schools to use the facilit…
# Long: None, Lati: None
# Virus Contact-Tracing For All – Singaporeans To Be Tracked By Gov’t In Post-COVID World
#
# Singapore is on the cusp o… https://t.co/B6p5LuK9Mh
# Long: None, Lati: None
# RT @kodiak149: Well @realDonaldTrump you finally sold out a stadium
# Long: None, Lati: None
# RT @AkbaruddinIndia: Boosting of India’s solar capacities unabated amidst pandemic.
# https://t.co/43GYL2U0Zh
# Long: None, Lati: None
# RT @rooshv: Coronavirus is a weapon against the right. https://t.co/VmmEB2YsSS
# Long: None, Lati: None
# RT @AynRandPaulRyan: “In a period of four months, it has devastated the whole world, and it isn’t over yet. Covid-19 is the disease Fauci a…
# Long: None, Lati: None
# RT @EmeraldRobinson: Number of funerals during pandemic:
#
# George Floyd: 4
#
# Your parents: 0
#
# Your grandparents: 0
#
# Your friends: 0
# Long: None, Lati: None
# RT @SteveRustad1: The GOP was outraged at Obama for a death toll of 4 in Benghazi.
#
# The pandemic death toll?
#
# 110,000.
#
# The GOP response?…
# Long: None, Lati: None
# RT @propublica: As states reopen, see if they meet White House guidelines for reopening and whether their COVID-19 infection rate is increa…
# Long: None, Lati: None
# RT @TexasTribune: Hospitalizations for the new coronavirus in Texas hit a high today with 2,056 people in the hospital, according to the st…
# Long: None, Lati: None
# RT @NoahShachtman: EXCLUSIVE: A military contractors’ report circulating in U.S. military &amp; intel networks claims to have evidence that COV…
# Long: None, Lati: None
# RT @BardsFM: New Q.
# #4444
# Attempting to establish new narrative 'riots' created[ing] second COVID-19 wave?
# Loss of control [first wave]?
# Re…
# Long: None, Lati: None
# RT @WalshFreedom: “It is who he is.” So stop asking him to “be better.” He can’t.
# Long: None, Lati: None
# RT @ajplus: New Zealand will be fully reopening their economy, without restrictions, after their COVID-19 cases reached zero.
#
# Prime Minist…
# Long: None, Lati: None
# RT @father_daughter: this is a really scary thing to envision. if you enjoy live music, head to https://t.co/SlA4KpnPdq to help independent…
# Long: None, Lati: None
# Barr: Durham team ‘working very aggressively’ despite coronavirus disruption https://t.co/QYM8OObiOd https://t.co/SQhf0IQysN
# Long: None, Lati: None
# RT @NandwalSimi: #SpiritToServeHumanity
# When entire nation was in lockdown due to covid-19 , 2000 @derasachasauda volunteers invested there…
# Long: None, Lati: None
# Behind NZ, like we are by pretty much every measure. Can we talk about that? Why can't we be like NZ? Why do we hav… https://t.co/f2HnmEkbus
# Long: None, Lati: None
# @MarkVilla97 @JoseBriales96 yo be coo.. #covid is a BIG deal wouldn’t wish it on anyone
# Long: None, Lati: None
# RT @JohnRHewson: Australia has a proud record of world class contributions to medical and scientific research and new technologies. In a po…
# Long: None, Lati: None
# RT @AsiaChloeBrown: You have got to be straight up stupid to flush either of these down the toilet. Just stupid as hell for no reason.
# Long: None, Lati: None
# RT @WGNNews: Chicago cancels all large summer events including Lollapalooza, Taste of Chicago due to coronavirus concerns https://t.co/btGZ…
# Long: None, Lati: None
# To those who want to reopen everything now...
#
# ...you’d better pay close attention to what’s happening in AZ.
#
# Th… https://t.co/W5DrBQFdSY
# Long: None, Lati: None
# RT @EmeraldRobinson: Number of funerals during pandemic:
#
# George Floyd: 4
#
# Your parents: 0
#
# Your grandparents: 0
#
# Your friends: 0
# Long: None, Lati: None
# I love a good pivot story
# Long: None, Lati: None
# RT @AkbaruddinIndia: Boosting of India’s solar capacities unabated amidst pandemic.
# https://t.co/43GYL2U0Zh
# Long: None, Lati: None
# RT @MajorPatriot: [They] want a second wave?
# It won't work. 👇
#
# Trump says he won’t close the country if second wave of coronavirus hits htt…
# Long: None, Lati: None
# RT @angryblkhoemo: I...I can't believe this needs to be said...
#
# WHY ARE Y'ALL FLUSHING PPE?
# Long: None, Lati: None
# RT @MichaelDadiego: “My Final PLEA to Patriots” Some 80% of Americans say Country is  'Out of Control’ Is this what WE REALLY WANT? You can…
# Long: None, Lati: None
# No truth to the rumor that he and Dr. Birx and not-a-doctor Barbara Ferrer are pitching a show to Paramount called… https://t.co/jCUDeiU8nB
# Long: None, Lati: None
# RT @joelockhart: Why is it not news that there seems to be a second wave of the coronavirus?
# Long: None, Lati: None
# RT @KTLA: "Now we have something that turned out to be my worst nightmare," Fauci said. "In the period of four months, it has devastated th…
# Long: None, Lati: None
# RT @MajorPatriot: [They] want a second wave?
# It won't work. 👇
#
# Trump says he won’t close the country if second wave of coronavirus hits htt…
# Long: None, Lati: None
# RT @steviegolding1: wait there’s a covid outbreak in san marcos?? where everyone squared and went out like nothing ever happened?? totally…
# Long: None, Lati: None
# RT @senatemajldr: The American people’s response to COVID-19 has been brave and patriotic. For months, citizens have sacrificed an enormous…
# Long: None, Lati: None
# RT @TomFitton: I am not Q/JFK Jr. and there is no "plan."
# Long: None, Lati: None
# RT @susansaga1: So now...Does anyone actually think COVID is going to be the real problem scaring people from voting in 2020?
#
# 👉RT
# 👉Leave y…
# Long: None, Lati: None
# RT @AxiomCatwalk: Have you heard the joke about getting rid of COVID??
#
# It's a riot!😂
# Long: None, Lati: None
# RT @philipaklein: Trump entered politics as a birther. He won GOP nom after linking Ted Cruz’s dad to the Kennedy assassination. He took ti…
# Long: None, Lati: None
# I don’t have a lot of girl mutuals but does anyone have any suggestions for stores that sell cute party dresses or… https://t.co/kK1cLYU7iB
# Long: None, Lati: None
# RT @nntaleb: This is NOT a data point. It is a huge statistical signal.
# Wear masks. And require that others do so.
# Long: None, Lati: None
# RT @CNN: The US government's current supply of remdesivir, the only drug known to work against Covid-19, will run out at the end of the mon…
# Long: None, Lati: None
# RT @cnni: New Zealand Prime Minister Jacinda Ardern has announced that almost all coronavirus restrictions in the country will be lifted to…
# Long: None, Lati: None
# RT @KikiAdine: 🔴REMINDER🔴
#
# 📍potus is a rapist
# 📍he raped a 13yo
# 📍he claims covid is a hoax
# 📍he claims trumpRussia is a hoax
# 📍he claims poli…
# Long: None, Lati: None
# RT @Sabrina67408695: Wearing gloves in public won't protect you from COVID-19, experts say https://t.co/36GRbvOZ2A
# Long: None, Lati: None
# RT @dabeard: These 14 states just hit their highest 7-day average of #COVID19 cases:
# Alaska
# Arizona
# Arkansas
# California
# Florida
# Kentucky
# Ne…
# Long: None, Lati: None
# RT @RobertGadoua: @Deplorable_Bree @zappafreak83 Since when has ANY Liberal tax been "temporary"? Name just one !Nice try though! Want to b…
# Long: None, Lati: None
# RT @mitchellvii: Isn't it amazing how the #Media put COVID-19 in timeout for 2 weeks so the #Antifa maniacs could burn our cities, and now…
# Long: None, Lati: None
# RT @iamaaditya99: 1/2 #GandhiHospital The incidents of beating doctors are really painful and should not take place as they are working tir…
# Long: None, Lati: None
# RT @AsiaChloeBrown: You have got to be straight up stupid to flush either of these down the toilet. Just stupid as hell for no reason.
# Long: None, Lati: None
# RT @aetiology: Good. This was terrible messaging. We know that presymptomatic people *who may not YET have symptoms* can definitely transmi…
# Long: None, Lati: None
# RT @BardsFM: Covid-19 second wave.
#
# You have a choice...
# Put your faith in corrupt Politicians, or,
#
# Get a damn backbone, ignore a second C…
# Long: None, Lati: None
# @RMinuski I’m unfortunately moving out of NYC cus if COVID, but I’ll be back v soon. Rain check!?🥰
# Long: None, Lati: None
# RT @DrJCoftheDC: COVID-19: Jared, your graduation is cancelled.
#
# Jared: But, have you met my momma? https://t.co/j8UJM29Z2G
# Long: None, Lati: None
# RT @gruntvegan: The vegan #revolution is gaining momentum.
#
# #Plantbased meat alternatives, both refrigerated and frozen, have experienced r…
# Long: None, Lati: None
# RT @pittman_george: 😆Twitter’s Attempt to ‘Fact-Check’ Coronavirus 5G Conspiracies Backfires https://t.co/aaX5PgzPBS
# Long: None, Lati: None
# RT @Brizzyc: Social journalism students, faculty and alumni from @newmarkjschool are helping @THECITYNY engage communities and report on CO…
# Long: None, Lati: None
# RT @KenRoth: Satellite imagery showing visits to Wuhan hospitals as well as Chinese internet search inquiries about coronavirus-type sympto…
# Long: None, Lati: None
# Free Webinar: Future of Airlines and Transportation sector after Global Pandemic on Friday, 12th June. Time: 1:00 P… https://t.co/D9QsSQjlNr
# Long: None, Lati: None
# @mmpadellan On Fox News:
#
# —White protesters demanding haircuts are patriots
#
# —Black protesters demanding an end to… https://t.co/MdWQPFYTwx
# Long: None, Lati: None
# 5G Protection Device with Anti-COVID coating.
# Long: None, Lati: None
# RT @JRCthr33: Eat shit. You should be locked up right along with Adolph Sheep https://t.co/803NuCw7TU
# Long: None, Lati: None
# RT @dailykos: A judge had to order ICE to do the bare minimum to protect detainees against COVID-19 https://t.co/Z8bZGz0cYb
# Long: None, Lati: None
# RT @GrimoldiPaolo: Parliament of #Lombardy voted by a majority law proposed by #LEGA that begins process for the request for compensation F…
# Long: None, Lati: None
# The low bar of capitalism — we were told today that we needed to be thankful we were employed during the pandemic.… https://t.co/6AxCWvmYE8
# Long: None, Lati: None
# RT @DoYouEvenLif: Jared Kushner went from the trying to “make peace”in the Middle East, to “being in” the Coronavirus Task Force, to Police…
# Long: None, Lati: None
# @KamVTV Here’s a question. At what point does the “pandemic” title be removed? How long will they milk this classif… https://t.co/XkF6K2utxy
# Long: None, Lati: None
# RT @JoeBiden: Because of Donald Trump's negligence and incompetence:
#
# - More than 110,000 people have died
# - We have nearly 2 million case…
# Long: None, Lati: None
# RT @Amy_Siskind: Fauci today:
# "“Where is it going to end? We’re still at the beginning of it." https://t.co/OsXMP21zam
# Long: None, Lati: None
# RT @JoeBiden: Because of Donald Trump's negligence and incompetence:
#
# - More than 110,000 people have died
# - We have nearly 2 million case…
# Long: None, Lati: None
# RT @belle_gyanna: SAY IT LOUDER https://t.co/mkQ2YzukLJ
# Long: None, Lati: None
# RT @KikiAdine: 🔴REMINDER🔴
#
# 📍potus is a rapist
# 📍he raped a 13yo
# 📍he claims covid is a hoax
# 📍he claims trumpRussia is a hoax
# 📍he claims poli…
# Long: None, Lati: None
# Yes @karishmasingh22 So will that make cricket more exciting and competitive ? What if, God forbid, half the team s… https://t.co/bYvMmQxf9M
# Long: None, Lati: None
# RT @speechboy71: Taking precautions saves lives ... who’d have figured? https://t.co/myb7Jo4BPw
# Long: None, Lati: None
# RT @JoeBiden: Because of Donald Trump's negligence and incompetence:
#
# - More than 110,000 people have died
# - We have nearly 2 million case…
# Long: None, Lati: None
# RT @TorelloSports: #USF announces voluntary on-campus football activities as of tomorrow, June 10.
#
# “All returning student-athletes and sta…
# Long: None, Lati: None
# RT @AxiomCatwalk: Have you heard the joke about getting rid of COVID??
#
# It's a riot!😂
# Long: None, Lati: None
# RT @FunctionUp: COVID testing tomorrow at Mesquite Memorial Stadium from 10AM-4PM! https://t.co/OskAncGkoo
# Long: None, Lati: None
# “When someone shows you who they are, believe them”
# Long: None, Lati: None
# Starting now!
# Long: None, Lati: None
# Virginia Trooper Resigns After Saying He Coughed on Driver to Spread Coronavirus https://t.co/5lTFBrp6AL
# Long: None, Lati: None
# RT @RepValDemings: The president had five months of relative peace and calm in this country to develop and lead a response to the covid pan…
# Long: None, Lati: None
# California coronavirus cases remain on upward trajectory - Los Angeles Times https://t.co/ljN9LKwKR5
# Long: None, Lati: None
# RT @ochocinco: Only thing fucking me has been this pandemic 😢 https://t.co/YDQ1b0CWvW
# Long: None, Lati: None
# RT @AsiaChloeBrown: You have got to be straight up stupid to flush either of these down the toilet. Just stupid as hell for no reason.
# Long: None, Lati: None
# Outstanding!
# Long: None, Lati: None
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ff56b86508dd> in <module>
#       1 myStreamListener = MyStreamListener()
#       2 myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ----> 3 myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
#       4 # Close the MySQL connection as it finished
#       5 # However, this won't be reached as the stream listener won't stop automatically
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     347                     raise TweepError('Expecting length, unexpected value found')
#     348
# --> 349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
#     351                 self._data(next_status_obj)
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_len(self, length)
#     181                 return self._pop(length)
#     182             read_len = max(self._chunk_size, length - len(self._buffer))
# --> 183             self._buffer += self._stream.read(read_len)
#     184         return six.b('')
#     185
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /Applications/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     579
#     580                 if len(mvb) <= chunk_left:
# --> 581                     n = self._safe_readinto(mvb)
#     582                     self.chunk_left = chunk_left - n
#     583                     return total_bytes + n
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _safe_readinto(self, b)
#     624                 n = self.fp.readinto(temp_mvb)
#     625             else:
# --> 626                 n = self.fp.readinto(mvb)
#     627             if not n:
#     628                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# /Applications/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     310                 raise timeout('The read operation timed out')
#     311             else:
# --> 312                 return self.recv_into(*args, **kwargs)
#     313
#     314     def settimeout(self, timeout):
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
