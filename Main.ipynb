# %%
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL
import credentials # Import api/access_token keys from credentials.py
import settings # Import related setting constants from settings.py 

import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob
# Streaming With Tweepy 
# http://docs.tweepy.org/en/v3.4.0/streaming_how_to.html#streaming-with-tweepy


# Override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):
    '''
    Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
    https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
    '''
    
    def on_status(self, status):
        '''
        Extract info from tweets
        '''
        
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        sentiment = TextBlob(text).sentiment
        polarity = sentiment.polarity
        subjectivity = sentiment.subjectivity
        
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if mydb.is_connected():
            mycursor = mydb.cursor()
            sql = "INSERT INTO {} (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, \
                user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
            mycursor.execute(sql, val)
            mydb.commit()
            mycursor.close()
    
    
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, stop srcraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
def clean_tweet(self, tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="1devansh",
    database="TwitterDB",
    port=3306
    
)
if mydb.is_connected():
    '''
    Check if this table exits. If not, then create a new one.
    '''
    mycursor = mydb.cursor()
    mycursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(settings.TABLE_NAME))
    if mycursor.fetchone()[0] != 1:
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
        mydb.commit()
    mycursor.close()

# %%
auth  = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOEKN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
# Close the MySQL connection as it finished
# However, this won't be reached as the stream listener won't stop automatically
# Press STOP button to finish the process.
mydb.close()
# Out:
# CapSF @agurevich23 No one is positing that the inverted yield curve forecasted a pandemic but it was… https://t.co/D5HqS5KURI
# Long: None, Lati: None
# RT @nowthisnews: ‘[Trump] just basically waved a white flag and retreated’ — @JoeBiden lambasted Pres. Trump for his ‘absolutely tragic’ re…
# Long: None, Lati: None
# RT @cloverlm: for those of you who refuse to wear masks during this pandemic. https://t.co/3A55c5wCwu
# Long: None, Lati: None
# RT @wewantMor_: did teachers &amp; nurses get a bonus as thanks to their hard work during COVID?
# Long: None, Lati: None
# @TODAYshow So AMC is above the rules of the land too? Next Wed. masks will be required going into a business....any… https://t.co/KQOJaU8B4I
# Long: None, Lati: None
# @Theobromia @HalFurman @latimes The CDC death rate 3 weeks ago was .26%. If you are under 50, you have a better cha… https://t.co/lRHYNx8acz
# Long: None, Lati: None
# RT @TimKennedyMMA: Just maybe give them to nurses, police officers, doctors, and our military..... but sure give them to professional athle…
# Long: None, Lati: None
# RT @Fayemous___: Doctors? Teachers? Essential workers?
# Long: None, Lati: None
# RT @aleistalking: .@GovInslee GOT UP the moment Kamau started asking about deportations, LEFT the moment I asked for $100M for undocu immig…
# Long: None, Lati: None
# RT @Cavanaugh4NE: This is absolutely outrageous. At a time when our local public health experts at UNMC are telling us to wear masks, Ricke…
# Long: None, Lati: None
# RT @Fayemous___: Doctors? Teachers? Essential workers?
# Long: None, Lati: None
# RT @wewantMor_: did teachers &amp; nurses get a bonus as thanks to their hard work during COVID?
# Long: None, Lati: None
# RT @ProjectLincoln: It's clear Donald Trump doesn't even want to be president.
# Long: None, Lati: None
# RT @Maxfloz: mass produce pls? id like one.
# And before you say, “Theyre tracking us!” remember youre tweeting it from a smartphone dummy
# Long: None, Lati: None
# RT @OLAASM: They gave people $1200 dollars three months ago for the people to survive an ongoing pandemic. They gave police $500 to survive…
# Long: None, Lati: None
# RT @AJDelgado13: In March, JASON MILLER filed a Motion for Protective Order w/ the court, arguing he should not have to sit for an in-perso…
# Long: None, Lati: None
# RT @therecount: Trump scrolls through his phone while small business owners share their pandemic stories. https://t.co/zKNJnT781E
# Long: None, Lati: None
# RT @JordanSchachtel: COVID-19 Thursday deaths in USA over past 2 months :
# Today: 747
# June 11: 904
# June 4: 1032
# May 28: 1225
# May 21: 1414
# Ma…
# Long: None, Lati: None
# RT @RonBrownstein: If my math is right, TX AZ &amp; FL, each with GOP governors who have followed Trump's cue in reopening early &amp; widely &amp; hav…
# Long: None, Lati: None
# RT @ABC7NY: Coronavirus News: Cuomo considers quarantine for travelers from Florida https://t.co/0T5Weu1gXa https://t.co/d7JWvhlkSm
# Long: None, Lati: None
# @drdavidsamadi @realDonaldTrump @SaraCarterDC @gregkellyusa @newsmax The truth about COVID-19=Dr. Samadi
# Long: None, Lati: None
# RT @DeanMacpherson: Interestingly, President Ramaphosa must believe that COVID-19 can tell the difference between a hotel room and an Airbn…
# Long: None, Lati: None
# RT @mcspocky: Apparently it really hurts tRump's feelings when people expose him for the coward that he is.
# Raise your hand if you sgree tR…
# Long: None, Lati: None
# RT @kylekuzma: Look like a tracking device🧐
# Long: None, Lati: None
# RT @wewantMor_: did teachers &amp; nurses get a bonus as thanks to their hard work during COVID?
# Long: None, Lati: None
# Long: None, Lati: None
# @EricCeleste How many DFW residents will be in Tulsa for  Trump’s Coronavirus Mixer?
# Long: None, Lati: None
# RT @anylaurie16: I cannot believe how fast this happened. My COVID-free Mom entered a skilled nursing facility on Monday, to get strong eno…
# Long: None, Lati: None
# RT @TheJWittz: Just wanted to remind you that:
#
# -Black lives matter!
# -LGBTQIA+ lives matter!
#
# -If you want to claim you care about "all liv…
# Long: None, Lati: None
# RT @Fayemous___: Doctors? Teachers? Essential workers?
# Long: None, Lati: None
# RT @sailorrooscout: Guys.
#
# There are 2.18M confirmed cases of Coronavirus in the United States as of this morning. As states begin to prem…
# Long: None, Lati: None
# RT @EricLiptonNYT: The decision by President Trump to turn mask wearing into a political statement/purity test is among the consequential/h…
# Long: None, Lati: None
# Covid has opened our eyes to things that truly matter. Caviar, fast cars and foreign holidays come nowhere close to… https://t.co/XXoEqBF3Hw
# Long: None, Lati: None
# RT @FinallyRJ: I was going to ignore this, but I'm going to politely disagree with my own judgment.
#
# The reason why you can't compare them…
# Long: None, Lati: None
# RT @Public_Citizen: This is positively insane. The White House reportedly wants to include $40,000,000,000 in defense spending in the next…
# Long: None, Lati: None
# @SexCounseling @realDonaldTrump Beautiful just like the covid tests. You're delusional
# Long: None, Lati: None
# @AlwaysOakOnline had hopes I got duped but alas https://t.co/DJcACq6ARE
# Long: None, Lati: None
# RT @Craig_A_Spencer: Hi, public health person here to help clarify:
#
# So, this is NOT a ‘great update’.
#
# ‘Stabilizing’ at 20k new cases is a…
# Long: None, Lati: None
# RT @Uncle_Jebus: Rural Oregon church unapologetically causes massive Covid-19 outbreak via /r/atheism https://t.co/vtidH6cRhS #atheist #hum…
# Long: None, Lati: None
# RT @Fayemous___: Doctors? Teachers? Essential workers?
# Long: None, Lati: None
# RT @jheil: Message: I care.
# Long: None, Lati: None
# RT @PhilstarNews: Although the Office of Vice President @lenirobredo has been working on its own COVID-19 relief since the start of the qua…
# Long: None, Lati: None
# RT @girlsreallyrule: Florida reported 3,207 new cases of COVID-19 on Thursday morning, again breaking its record for the highest single-day…
# Long: None, Lati: None
# When you want a new job but the jobs you see all want you to go work in house and ignoring the fact that Covid is still a thing.
# Long: None, Lati: None
# The grandfather is a force for good: "in his role as chief operating officer of Premier Family Health in Wellington… https://t.co/RKHUFzbRPA
# Long: None, Lati: None
# RT @33rai33: #DefundThePolice I was strangled in my apartment after police refused to do anything about my physical violence reports. I was…
# Long: None, Lati: None
# RT @cryborg: Trump’s rally is going to be a coronavirus bloodbath
# Long: None, Lati: None
# RT @silviagalfaro: DEFEND DACA. DO NOT BUILD THE WALL. BAN ICE. OH &amp; GET MY PEOPLE OUT OF THESE COVID INFESTED CAGES. KIDS ARE GETTING RAPE…
# Long: None, Lati: None
# RT @CNN: An Arizona sheriff who said he wouldn't enforce the state's stay-at-home order has tested positive for Covid-19 https://t.co/OZfAc…
# Long: None, Lati: None
# Govt tells its departments not to spend money and raises prices of fuel. Is this the best way of coming out of a fi… https://t.co/DtjDsp8Fox
# Long: None, Lati: None
# RT @SenKamalaHarris: Today, the Senate did not vote on additional COVID-19 relief.
# We did not vote on oversight that this administration so…
# Long: None, Lati: None
# @ADH6626 Sad part is I don't know if you're talking about covid or prison.
# Long: None, Lati: None
# RT @Fayemous___: Doctors? Teachers? Essential workers?
# Long: None, Lati: None
# RT @wewantMor_: did teachers &amp; nurses get a bonus as thanks to their hard work during COVID?
# Long: None, Lati: None
# Long: None, Lati: None
# RT @madrid_mike: When you can’t wait for that next @ProjectLincoln ad to drop
# Long: None, Lati: None
# RT @chescaleigh: it’s weird watching people just decide the pandemic is over
# Long: None, Lati: None
# RT @StopVaxxedLies: @BlueLionBlog @DreadPirRob42 @SocialHermitCal @EdDarrell @lawnatural @LifeDorr @krebiozen @BeckyJohnson222 @WendyOrent…
# Long: None, Lati: None
# RT @Fayemous___: Doctors? Teachers? Essential workers?
# Long: None, Lati: None
# RT @wewantMor_: did teachers &amp; nurses get a bonus as thanks to their hard work during COVID?
# Long: None, Lati: None
# RT @RepSwalwell: When the Putin/Erdogan/Kim group text is blowing up.
# Long: None, Lati: None
# RT @BillBishopKHOU: Way out west in Marfa, Texas
# "In light of the recent spike of COVID-19 cases in Marfa, a face mask ordinance has been a…
# Long: None, Lati: None
# RT @cloverlm: for those of you who refuse to wear masks during this pandemic. https://t.co/3A55c5wCwu
# Long: None, Lati: None
# And just like that, my older half brother has positive test results for covid and everyone at the funeral has been exposed....
# Long: None, Lati: None
# RT @BarbMcQuade: Federal judges in Eastern District of Michigan are conducting drive-through immigration ceremonies to swear in new citizen…
# Long: None, Lati: None
# RT @Fayemous___: Doctors? Teachers? Essential workers?
# Long: None, Lati: None
# RT @SamarthSolank20: @DrRPNishank @ugc_india @AICTE_INDIA @cbseindia29 @DG_NTA @narendramodi @AmitShah @PMOIndia @HMOIndia @HRDMinistry @my…
# Long: None, Lati: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ff56b86508dd> in <module>
#       1 myStreamListener = MyStreamListener()
#       2 myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ----> 3 myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
#       4 # Close the MySQL connection as it finished
#       5 # However, this won't be reached as the stream listener won't stop automatically
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in on_data(self, raw_data)
#      52         if 'in_reply_to_status_id' in data:
#      53             status = Status.parse(self.api, data)
# ---> 54             if self.on_status(status) is False:
#      55                 return False
#      56         elif 'delete' in data:
#
# <ipython-input-1-40bf38cd996a> in on_status(self, status)
#      59                 user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
#      60             mycursor.execute(sql, val)
# ---> 61             mydb.commit()
#      62             mycursor.close()
#      63
#
# /Applications/anaconda3/lib/python3.7/site-packages/mysql/connector/connection.py in commit(self)
#     957     def commit(self):
#     958         """Commit current transaction"""
# --> 959         self._execute_query("COMMIT")
#     960
#     961     def rollback(self):
#
# /Applications/anaconda3/lib/python3.7/site-packages/mysql/connector/connection.py in _execute_query(self, query)
#     976         """
#     977         self.handle_unread_result()
# --> 978         self.cmd_query(query)
#     979
#     980     def info_query(self, query):
#
# /Applications/anaconda3/lib/python3.7/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     596         if not isinstance(query, bytes):
#     597             query = query.encode('utf-8')
# --> 598         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     599
#     600         if self._have_next_result:
#
# /Applications/anaconda3/lib/python3.7/site-packages/mysql/connector/connection.py in _send_cmd(self, command, argument, packet_number, packet, expect_response, compressed_packet_number)
#     352         if not expect_response:
#     353             return None
# --> 354         return self._socket.recv()
#     355
#     356     def _send_data(self, data_file, send_empty_packet=False):
#
# /Applications/anaconda3/lib/python3.7/site-packages/mysql/connector/network.py in recv_plain(self)
#     263             packet_len = 0
#     264             while packet_len < 4:
# --> 265                 chunk = self.sock.recv(4 - packet_len)
#     266                 if not chunk:
#     267                     raise errors.InterfaceError(errno=2013)
#
# /Applications/anaconda3/lib/python3.7/ssl.py in recv(self, buflen, flags)
#    1035                     "non-zero flags not allowed in calls to recv() on %s" %
#    1036                     self.__class__)
# -> 1037             return self.read(buflen)
#    1038         else:
#    1039             return super().recv(buflen, flags)
#
# /Applications/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     911                 return self._sslobj.read(len, buffer)
#     912             else:
# --> 913                 return self._sslobj.read(len)
#     914         except SSLError as x:
#     915             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
