# %%
# Load data from MySQL to perform exploratory data analysis
import settings
import mysql.connector
import pandas as pd
import time

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl


db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="1devansh",
    database="TwitterDB",
    charset = 'utf8'
)

# %%
# Load data from MySQL
df = pd.read_sql('SELECT id_str, text, created_at, polarity, user_location FROM {}'.format(settings.TABLE_NAME), con=db_connection)
# UTC for date time at default
df['created_at'] = pd.to_datetime(df['created_at'])
print("Airbnb Negative Tweets Monitor: ")
for index, tweets in df[df['polarity'] == -1].iterrows():
    print("  " +str(tweets[2]) + "  " + tweets[1])


# Clean and transform data to enable time series
result = df.groupby([pd.Grouper(key='created_at', freq='10min'), 'polarity']).count() \
        .unstack(fill_value=0).stack().reset_index()
result['created_at'] = pd.to_datetime(result['created_at']).apply(lambda x: x.strftime('%m-%d %H:%M'))


# Plot Line Chart for monitoring brand awareness on Twitter
mpl.rcParams['figure.dpi']= 200
plt.figure(figsize=(16, 6))
sns.set(style="darkgrid")
ax = sns.lineplot(x = "created_at" ,y="id_str", hue='polarity', data=result,\
                  palette=sns.color_palette(["#FF5A5F","#484848", "#767676"]))
ax.set(xlabel='Time Series in UTC', ylabel="Number of '{}' mentions".format(settings.TRACK_WORDS[0]))
plt.legend(title='Attitude towards Airbnb', loc='upper left', labels=['Negative', 'Normal', 'Positive'])
sns.set(rc={"lines.linewidth": 1})
plt.show()
# Out:
# thout symptoms cant transmit coronavirus?
#
# WRONG!
#
# Thats based on a misunders
#   2020-06-10 02:00:47  Something weird happened with the data today
#   2020-06-10 02:00:47  RT @Blopinski: Todays federal Conservatives are quite possibly the worst opposition party in the history of Canada.  https://t.co/LBQLh6uR
#   2020-06-10 02:00:47  RT @nytimes: In a wide-ranging talk to biotech executives, Dr. Anthony Fauci delivered a grim assessment of the devastation wrought around
#   2020-06-10 02:00:47  RT @ABCNewsLive: "If someone here does get very sick, there's no way of helping them immediately."  Ana Paula Sana
#
# @JamesAALongman report
#   2020-06-10 02:00:48  RT @AstroKatie: Have you seen headlines claiming people without symptoms cant transmit coronavirus?
#
# WRONG!
#
# Thats based on a misunders
#   2020-06-10 02:00:49  RT @CNN: Coronavirus is my worst nightmare, worse in ways than Ebola or HIV, said Dr. Anthony Fauci, director of the National Institute o
#   2020-06-10 02:00:50  RT @morethanmySLE: Ebola was "scary," HIV was "insidiously" spread, but #coronavirus is Dr. Fauci's "worst nightmare"!
#
# https://t.co/RE1RDI
#   2020-06-10 02:00:52  @Fla_Pol @JoseJavierJJR @realRyanNicol Hope you turned to @SenRickScott that put together that terrible system. Let https://t.co/hg1BzyKPnm
#   2020-06-10 02:00:52  RT @CNN: Coronavirus is my worst nightmare, worse in ways than Ebola or HIV, said Dr. Anthony Fauci, director of the National Institute o
#   2020-06-10 02:00:53  RT @AstroKatie: Have you seen headlines claiming people without symptoms cant transmit coronavirus?
#
# WRONG!
#
# Thats based on a misunders
#   2020-06-10 02:00:53  RT @ZachSteppOH: Participating in Democracy should not be difficult. When were faced with a pandemic, we ought to adapt and make it easier
#   2020-06-10 02:00:55  RT @MarketWatch: Fauci calls pandemic his worst nightmare, warns it isnt over yet https://t.co/hcMS0YTqGh
#   2020-06-10 02:00:56  @David_Ballif @pete_vm @Jacqueline_SVH The sad thing is that it's not a pipe dream if the funding can ever reliably https://t.co/i0fUqEmShk
#   2020-06-10 02:00:57  RT @nytimes: In a wide-ranging talk to biotech executives, Dr. Anthony Fauci delivered a grim assessment of the devastation wrought around
#   2020-06-10 02:00:57  three cheers for state-sanctioned filthy Shakespearean cosplay
#   2020-06-10 02:00:58  RT @nytimes: In a wide-ranging talk to biotech executives, Dr. Anthony Fauci delivered a grim assessment of the devastation wrought around
#   2020-06-10 02:00:59   WHO has been disastrous during this pandemic!
#   2020-06-10 02:01:00  RT @nytimes: In a wide-ranging talk to biotech executives, Dr. Anthony Fauci delivered a grim assessment of the devastation wrought around
#   2020-06-10 02:01:01  RT @nytimes: In a wide-ranging talk to biotech executives, Dr. Anthony Fauci delivered a grim assessment of the devastation wrought around
#   2020-06-10 02:01:01  RT @IAMCouncil: This is blatantly Islamophobic &amp; aimed at demonising &amp; vilifying Muslims. https://t.co/ums8lGEaJR
#   2020-06-10 02:01:02  RT @nytimes: In a wide-ranging talk to biotech executives, Dr. Anthony Fauci delivered a grim assessment of the devastation wrought around
#   2020-06-10 02:01:03  RT @nytimes: In a wide-ranging talk to biotech executives, Dr. Anthony Fauci delivered a grim assessment of the devastation wrought around
#   2020-06-10 02:01:04  RT @HollywdHealth: Our panelists taking a moment to reflect and decompress before tackling a difficult topic: racism and maternal health in
#   2020-06-10 02:01:06  And then you contrast our dire situation with stupid in charge of our response to the #coronavirus, with whats goi https://t.co/JBAZrp5U9c
#   2020-06-10 02:01:07  RT @CNN: Coronavirus is my worst nightmare, worse in ways than Ebola or HIV, said Dr. Anthony Fauci, director of the National Institute o
#   2020-06-10 02:01:07  To all of my family members who are so disappointed in me over my support of increased funding for education, commo https://t.co/S1xoWmLRSp
#   2020-06-10 02:01:08  RT @SitaramYechury: BJP has ruled Gujarat since 1995 and Modi used that as a model for making false claims. Modi called Kerala, Somalia!
#   2020-06-10 02:01:09  RT @johncardillo: Anthony Fauci warns that COVID-19 pandemic isn't close to over
#
# Mr. Wrong About Everything will never let a crisis go t
#   2020-06-10 02:01:09  @OneEyedLizzy @sophia_yan Sorry to hear that , COVID is a horrible life changer .
#   2020-06-10 02:01:11  RT @Pismo_B:  Fake News Hypocrisy!
#
# Hypocrite reporter busted for spreading coronavirus fear!!!
#
# https://t.co/yyPqCLElqe
#   2020-06-10 02:01:12  @leannestockart I too am wondering! Nobody has answers. Unfortunately my department decided to close permanently wh https://t.co/pTACKsD8CV
#   2020-06-10 02:01:16  RT @CNN: Coronavirus is my worst nightmare, worse in ways than Ebola or HIV, said Dr. Anthony Fauci, director of the National Institute o
#   2020-06-10 02:01:19  RT @SteveRustad1: The GOP was outraged at Obama for a death toll of 4 in Benghazi.
#
# The pandemic death toll?
#
# 110,000.
#
# The GOP response?
#   2020-06-10 02:01:19  RT @nycsouthpaw: Seems bad
#   2020-06-10 02:01:20  @JoeBiden Because of the @coronavirus u moron Remember when you opposed the banning of flights from China where t https://t.co/suKBLzwQbK
#   2020-06-10 02:01:21  RT @AstroKatie: Have you seen headlines claiming people without symptoms cant transmit coronavirus?
#
# WRONG!
#
# Thats based on a misunders
#   2020-06-10 02:01:22  RT @SteveRustad1: The GOP was outraged at Obama for a death toll of 4 in Benghazi.
#
# The pandemic death toll?
#
# 110,000.
#
# The GOP response?
#   2020-06-10 02:01:23  RT @AstroKatie: Have you seen headlines claiming people without symptoms cant transmit coronavirus?
#
# WRONG!
#
# Thats based on a misunders
#   2020-06-10 02:01:23  RT @Amy_Siskind: The Fox News hosts have blown up their minds between the pandemic and the protests.  You hate to see it.
#   2020-06-10 02:01:26  RT @CNN: Coronavirus is my worst nightmare, worse in ways than Ebola or HIV, said Dr. Anthony Fauci, director of the National Institute o
#   2020-06-10 02:01:26  "In a wide-ranging talk to biotech executives, Dr. Anthony Fauci delivered a grim assessment of the devastation wro https://t.co/5wmn6M3GMp
#   2020-06-10 02:01:27  RT @AstroKatie: Have you seen headlines claiming people without symptoms cant transmit coronavirus?
#
# WRONG!
#
# Thats based on a misunders
#   2020-06-10 02:01:32  RT @AstroKatie: Have you seen headlines claiming people without symptoms cant transmit coronavirus?
#
# WRONG!
#
# Thats based on a misunders
#   2020-06-10 02:01:32  RT @FoilTha: As if anyone needed another reason to not accept this fake ass vaxx. NOPE.
#
# https://t.co/azwRu7siDX
#   2020-06-10 02:01:33  RT @thezarakhhan: Theyre giving pathetic treatment to covid patients.
#
# Didnt expect this from our government. #GandhiHospital
#   2020-06-10 02:01:33  RT @CNN: Coronavirus is my worst nightmare, worse in ways than Ebola or HIV, said Dr. Anthony Fauci, director of the National Institute o
#   2020-06-10 02:01:35  RT @WizBish: #JohnsonHasFailed
# #ToriesHaveFailed
#
# We will all fail if we dont withdraw consent to be misgoverned so lethally.
#
# #ToriesOut
#   2020-06-10 02:01:35  RT @nandtara: Yes @navikakumar stay on track with the evil fascist script. Feed our starving, pandemic stricken Indian citizens on the opiu
#   2020-06-10 02:01:36  RT @NYCDEATHROWCATS: Tiger was brought in with his two housemates and may have been exposed to covid-19. He is nervous and sad. Tiger needs
#   2020-06-10 02:01:36  RT @SteveRustad1: The GOP was outraged at Obama for a death toll of 4 in Benghazi.
#
# The pandemic death toll?
#
# 110,000.
#
# The GOP response?
#   2020-06-10 02:01:37  RT @KTLA: "Now we have something that turned out to be my worst nightmare," Fauci said. "In the period of four months, it has devastated th
#   2020-06-10 02:01:37  RT @iamaaditya99: 1/2 #GandhiHospital The incidents of beating doctors are really painful and should not take place as they are working tir
#   2020-06-19 03:06:22  @INCIndia @RahulGandhi Shame on Congress party and bad luck for congress party for having Pappu as their leader . B https://t.co/McyKMZ9z8O
#   2020-06-19 03:06:22  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:23  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:24  RT @sheriantoinette: COVID 19 is the worst disease process Ive ever worked with in my 8 years as an ICU nurse.
#
# When they say recovered
#   2020-06-19 03:06:25  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:26  RT @MSNBC: Oklahoma emergency room Dr. Samantha White says it's a terrible idea" to hold the planned Trump rally in Tulsa because coronavi
#   2020-06-19 03:06:26  Its crazy and scary how coronavirus is spiking up real bad. Ima go ahead and say it, it wasnt the time to go out https://t.co/yrPwcAXdeJ
#   2020-06-19 03:06:26  RT @StephenKing: People of Florida, stop being stupid about COVID! You have a governor and legislature to do that.
#   2020-06-19 03:06:28  @MSNBC Media is angry their pandemic hype failed....
#   2020-06-19 03:06:29  RT @StephenKing: People of Florida, stop being stupid about COVID! You have a governor and legislature to do that.
#   2020-06-19 03:06:29  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:29  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:29  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:31  RT @StephenKing: People of Florida, stop being stupid about COVID! You have a governor and legislature to do that.
#   2020-06-19 03:06:31  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:32  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:32  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:33  RT @timdunlop: Protesters: we should remove a few statues
# The govt: shocking destruction of our heritage; bring in the police.
# The govt: le
#   2020-06-19 03:06:34  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:35  RT @morganhousel: "Colleges are holding out hope of in-person classes in order to keep up enrollments ... If they tell the difficult truth
#   2020-06-19 03:06:35  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:36  @MSNBC anyone who attends that rally is an idiot.  if (s)he gets covid....no one else is to blame than him/her. https://t.co/TwLvR0AjcL
#   2020-06-19 03:06:37  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:38  RT @MSNBC: Oklahoma emergency room Dr. Samantha White says it's a terrible idea" to hold the planned Trump rally in Tulsa because coronavi
#   2020-06-19 03:06:38  RT @MSNBC: Oklahoma emergency room Dr. Samantha White says it's a terrible idea" to hold the planned Trump rally in Tulsa because coronavi
#   2020-06-19 03:06:38  RT @JaneCaro: What an entirely predictable bunch of nasty philistines these LNP politicians are. They wont help the Arts sector during the
#   2020-06-19 03:06:39  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:39  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:40  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:40  RT @MSNBC: Oklahoma emergency room Dr. Samantha White says it's a terrible idea" to hold the planned Trump rally in Tulsa because coronavi
#   2020-06-19 03:06:40  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:41  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:41  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:41  RT @StephenKing: People of Florida, stop being stupid about COVID! You have a governor and legislature to do that.
#   2020-06-19 03:06:41  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:42  RT @BadMomMercy: And yet retards like @JoeBiden still talk shit and spread lies .  Or his wife whoever the fuck is writing his trash for hi
#   2020-06-19 03:06:42  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:43  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:43  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:44  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:44  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:44  RT @mmpadellan: What grisly number of Americans dead from COVID-19 do we have to reach before idiots realize WEARING A MASK IS NOT POLITICA
#   2020-06-19 03:06:44  @Shivesh64488441 @deptoflabour They don't answer thier phone nor reply to e-mails its very frustrating because we n https://t.co/IPneq76lac
#   2020-06-19 03:06:45  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:45  RT @StephenKing: People of Florida, stop being stupid about COVID! You have a governor and legislature to do that.
#   2020-06-19 03:06:46  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:47  @realDonaldTrump @DelawareDOT Did you know there is a pandemic and you are holding your stupid rally indoors with 2 https://t.co/OzSDICoX9A
#   2020-06-19 03:06:47  Coronavirus: Trumps meatpacking order has failed workers @jgkfan @MeatSauce1 @Patrick_Reusse @PatKessler https://t.co/MUWq3KScYB
#   2020-06-19 03:06:49  RT @cousineggplant: going insane seeing the government shaming protestors for being irresponsible about covid when i go down the street and
#   2020-06-19 03:06:49  bc imagine if they would give this money to the ppl who are struggling during covid this is fucked up
#   2020-06-19 03:06:49  RT @Liberty5380: So disgusting https://t.co/alDkV5pvhk
#   2020-06-19 03:06:51  Without getting into ANC personality politics, as a boy from Sebokeng it has been extremely painful to see our fath https://t.co/KdkDZHqNy9
#   2020-06-19 03:06:51  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:51  RT @mmpadellan: What grisly number of Americans dead from COVID-19 do we have to reach before idiots realize WEARING A MASK IS NOT POLITICA
#   2020-06-19 03:06:51  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:51  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:52  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:52  RT @Alex_Panetta: The bad news, aside from the topline number, just look at those empathy scores. The cares-about-people-like-me numbers.
#   2020-06-19 03:06:53  Baldwin also called Trumps trade wars disastrous for Wisconsin farms and businesses  and the problems it creat https://t.co/pOyKcyHNfS
#   2020-06-19 03:06:54  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:55  RT @Sifill_LDF: Just thinking about the nurses wearing garbage bags, and using the same masks over &amp; over in NY during the worst of the pan
#   2020-06-19 03:06:55  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:57  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:58  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:06:59  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:00  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:00  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:01  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:00  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:01  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:01  RT @Vaibhav_AAP: This is shocking.. Mass #resignation of the Doctors of Lucknow's #Mayo Hospital against salary deduction, perks deduction
#   2020-06-19 03:07:01  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:01  It is insane that an event host called this tweet racially insensitive and canceled him over it.
#
# The Chinese gover https://t.co/cFFmz3H51H
#   2020-06-19 03:07:03  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:03  RT @StephenKing: People of Florida, stop being stupid about COVID! You have a governor and legislature to do that.
#   2020-06-19 03:07:04  RT @evansaacks: Coronavirus got a fake ID that said COVID-21
#   2020-06-19 03:07:04  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:04  RT @MSNBC: Oklahoma emergency room Dr. Samantha White says it's a terrible idea" to hold the planned Trump rally in Tulsa because coronavi
#   2020-06-19 03:07:04  RT @MSNBC: Oklahoma emergency room Dr. Samantha White says it's a terrible idea" to hold the planned Trump rally in Tulsa because coronavi
#   2020-06-19 03:07:05  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:06  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:06  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:06  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:06  RT @mmpadellan: Where's Joe Biden?
#
# He's out there in Pennsylvania, HAMMERING the fake Republican "president" on his bungled handling of CO
#   2020-06-19 03:07:07  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:07  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:08  RT @MikeForKY: The fact that this ranks sixth or seventh in national scandals this week speaks to how badly Mitch McConnell has damaged our
#   2020-06-19 03:07:09  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:10  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:10  I wasn't going to break my silence but I need to address this.
#
# This is the worst fucking year, much much worst tha https://t.co/141SktaMM8
#   2020-06-19 03:07:11  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:11  @WIbeerbaron parents and grandparents, take these stupid shits out of your wills. selfish idiots. i have a friend f https://t.co/AsJy2Mwr7p
#   2020-06-19 03:07:12  RT @ddale8: No, COVID isnt dying out. No, Biden isnt stuck in his basement. No, Obama didnt fail to do anything on policing. No, Trump
#   2020-06-19 03:07:12  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:13  RT @chescaleigh: its weird watching people just decide the pandemic is over
#   2020-06-19 03:07:14  RT @janefourmillion: @bridgettyh It does not sound stupid.  Healtcare workers wear goggles, face shields....
# https://t.co/sq8FiyZmKr
#   2020-06-19 03:07:14  Im sorry... WHAT.
#   2020-06-19 03:07:15  RT @dailykos: News from Bizarro World: Trump claims COVID-19 is 'dying out' and wearing a mask is dangerous https://t.co/zFnTQeEHaL
#   2020-06-19 03:07:16  RT @MSNBC: Oklahoma emergency room Dr. Samantha White says it's a terrible idea" to hold the planned Trump rally in Tulsa because coronavi

# %%
value = [
    ('US', 'United States'),
    ('AF', 'Afghanistan'),
    ('AL', 'Albania'),
    ('DZ', 'Algeria'),
    ('AS', 'American Samoa'),
    ('AD', 'Andorra'),
    ('AO', 'Angola'),
    ('AI', 'Anguilla'),
    ('AQ', 'Antarctica'),
    ('AG', 'Antigua And Barbuda'),
    ('AR', 'Argentina'),
    ('AM', 'Armenia'),
    ('AW', 'Aruba'),
    ('AU', 'Australia'),
    ('AT', 'Austria'),
    ('AZ', 'Azerbaijan'),
    ('BS', 'Bahamas'),
    ('BH', 'Bahrain'),
    ('BD', 'Bangladesh'),
    ('BB', 'Barbados'),
    ('BY', 'Belarus'),
    ('BE', 'Belgium'),
    ('BZ', 'Belize'),
    ('BJ', 'Benin'),
    ('BM', 'Bermuda'),
    ('BT', 'Bhutan'),
    ('BO', 'Bolivia'),
    ('BA', 'Bosnia And Herzegowina'),
    ('BW', 'Botswana'),
    ('BV', 'Bouvet Island'),
    ('BR', 'Brazil'),
    ('BN', 'Brunei Darussalam'),
    ('BG', 'Bulgaria'),
    ('BF', 'Burkina Faso'),
    ('BI', 'Burundi'),
    ('KH', 'Cambodia'),
    ('CM', 'Cameroon'),
    ('CA', 'Canada'),
    ('CV', 'Cape Verde'),
    ('KY', 'Cayman Islands'),
    ('CF', 'Central African Rep'),
    ('TD', 'Chad'),
    ('CL', 'Chile'),
    ('CN', 'China'),
    ('CX', 'Christmas Island'),
    ('CC', 'Cocos Islands'),
    ('CO', 'Colombia'),
    ('KM', 'Comoros'),
    ('CG', 'Congo'),
    ('CK', 'Cook Islands'),
    ('CR', 'Costa Rica'),
    ('CI', 'Cote D`ivoire'),
    ('HR', 'Croatia'),
    ('CU', 'Cuba'),
    ('CY', 'Cyprus'),
    ('CZ', 'Czech Republic'),
    ('DK', 'Denmark'),
    ('DJ', 'Djibouti'),
    ('DM', 'Dominica'),
    ('DO', 'Dominican Republic'),
    ('TP', 'East Timor'),
    ('EC', 'Ecuador'),
    ('EG', 'Egypt'),
    ('SV', 'El Salvador'),
    ('GQ', 'Equatorial Guinea'),
    ('ER', 'Eritrea'),
    ('EE', 'Estonia'),
    ('ET', 'Ethiopia'),
    ('FK', 'Falkland Islands (Malvinas)'),
    ('FO', 'Faroe Islands'),
    ('FJ', 'Fiji'),
    ('FI', 'Finland'),
    ('FR', 'France'),
    ('GF', 'French Guiana'),
    ('PF', 'French Polynesia'),
    ('TF', 'French S. Territories'),
    ('GA', 'Gabon'),
    ('GM', 'Gambia'),
    ('GE', 'Georgia'),
    ('DE', 'Germany'),
    ('GH', 'Ghana'),
    ('GI', 'Gibraltar'),
    ('GR', 'Greece'),
    ('GL', 'Greenland'),
    ('GD', 'Grenada'),
    ('GP', 'Guadeloupe'),
    ('GU', 'Guam'),
    ('GT', 'Guatemala'),
    ('GN', 'Guinea'),
    ('GW', 'Guinea-bissau'),
    ('GY', 'Guyana'),
    ('HT', 'Haiti'),
    ('HN', 'Honduras'),
    ('HK', 'Hong Kong'),
    ('HU', 'Hungary'),
    ('IS', 'Iceland'),
    ('IN', 'India'),
    ('ID', 'Indonesia'),
    ('IR', 'Iran'),
    ('IQ', 'Iraq'),
    ('IE', 'Ireland'),
    ('IL', 'Israel'),
    ('IT', 'Italy'),
    ('JM', 'Jamaica'),
    ('JP', 'Japan'),
    ('JO', 'Jordan'),
    ('KZ', 'Kazakhstan'),
    ('KE', 'Kenya'),
    ('KI', 'Kiribati'),
    ('KP', 'Korea (North)'),
    ('KR', 'Korea (South)'),
    ('KW', 'Kuwait'),
    ('KG', 'Kyrgyzstan'),
    ('LA', 'Laos'),
    ('LV', 'Latvia'),
    ('LB', 'Lebanon'),
    ('LS', 'Lesotho'),
    ('LR', 'Liberia'),
    ('LY', 'Libya'),
    ('LI', 'Liechtenstein'),
    ('LT', 'Lithuania'),
    ('LU', 'Luxembourg'),
    ('MO', 'Macau'),
    ('MK', 'Macedonia'),
    ('MG', 'Madagascar'),
    ('MW', 'Malawi'),
    ('MY', 'Malaysia'),
    ('MV', 'Maldives'),
    ('ML', 'Mali'),
    ('MT', 'Malta'),
    ('MH', 'Marshall Islands'),
    ('MQ', 'Martinique'),
    ('MR', 'Mauritania'),
    ('MU', 'Mauritius'),
    ('YT', 'Mayotte'),
    ('MX', 'Mexico'),
    ('FM', 'Micronesia'),
    ('MD', 'Moldova'),
    ('MC', 'Monaco'),
    ('MN', 'Mongolia'),
    ('MS', 'Montserrat'),
    ('MA', 'Morocco'),
    ('MZ', 'Mozambique'),
    ('MM', 'Myanmar'),
    ('NA', 'Namibia'),
    ('NR', 'Nauru'),
    ('NP', 'Nepal'),
    ('NL', 'Netherlands'),
    ('AN', 'Netherlands Antilles'),
    ('NC', 'New Caledonia'),
    ('NZ', 'New Zealand'),
    ('NI', 'Nicaragua'),
    ('NE', 'Niger'),
    ('NG', 'Nigeria'),
    ('NU', 'Niue'),
    ('NF', 'Norfolk Island'),
    ('MP', 'Northern Mariana Islands'),
    ('NO', 'Norway'),
    ('OM', 'Oman'),
    ('PK', 'Pakistan'),
    ('PW', 'Palau'),
    ('PA', 'Panama'),
    ('PG', 'Papua New Guinea'),
    ('PY', 'Paraguay'),
    ('PE', 'Peru'),
    ('PH', 'Philippines'),
    ('PN', 'Pitcairn'),
    ('PL', 'Poland'),
    ('PT', 'Portugal'),
    ('PR', 'Puerto Rico'),
    ('QA', 'Qatar'),
    ('RE', 'Reunion'),
    ('RO', 'Romania'),
    ('RU', 'Russian Federation'),
    ('RW', 'Rwanda'),
    ('KN', 'Saint Kitts And Nevis'),
    ('LC', 'Saint Lucia'),
    ('VC', 'St Vincent/Grenadines'),
    ('WS', 'Samoa'),
    ('SM', 'San Marino'),
    ('ST', 'Sao Tome'),
    ('SA', 'Saudi Arabia'),
    ('SN', 'Senegal'),
    ('SC', 'Seychelles'),
    ('SL', 'Sierra Leone'),
    ('SG', 'Singapore'),
    ('SK', 'Slovakia'),
    ('SI', 'Slovenia'),
    ('SB', 'Solomon Islands'),
    ('SO', 'Somalia'),
    ('ZA', 'South Africa'),
    ('ES', 'Spain'),
    ('LK', 'Sri Lanka'),
    ('SH', 'St. Helena'),
    ('PM', 'St.Pierre'),
    ('SD', 'Sudan'),
    ('SR', 'Suriname'),
    ('SZ', 'Swaziland'),
    ('SE', 'Sweden'),
    ('CH', 'Switzerland'),
    ('SY', 'Syrian Arab Republic'),
    ('TW', 'Taiwan'),
    ('TJ', 'Tajikistan'),
    ('TZ', 'Tanzania'),
    ('TH', 'Thailand'),
    ('TG', 'Togo'),
    ('TK', 'Tokelau'),
    ('TO', 'Tonga'),
    ('TT', 'Trinidad And Tobago'),
    ('TN', 'Tunisia'),
    ('TR', 'Turkey'),
    ('TM', 'Turkmenistan'),
    ('TV', 'Tuvalu'),
    ('UG', 'Uganda'),
    ('UA', 'Ukraine'),
    ('AE', 'United Arab Emirates'),
    ('UK', 'United Kingdom'),
    ('UY', 'Uruguay'),
    ('UZ', 'Uzbekistan'),
    ('VU', 'Vanuatu'),
    ('VA', 'Vatican City State'),
    ('VE', 'Venezuela'),
    ('VN', 'Viet Nam'),
    ('VG', 'Virgin Islands (British)'),
    ('VI', 'Virgin Islands (U.S.)'),
    ('EH', 'Western Sahara'),
    ('YE', 'Yemen'),
    ('YU', 'Yugoslavia'),
    ('ZR', 'Zaire'),
    ('ZM', 'Zambia'),
    ('ZW', 'Zimbabwe')
]
country =[]
for i in value:
    country.append(i[1])

# %%
print(country)
# Out:
# ['United States', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua And Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia And Herzegowina', 'Botswana', 'Bouvet Island', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Central African Rep', 'Chad', 'Chile', 'China', 'Christmas Island', 'Cocos Islands', 'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Cote D`ivoire', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'French S. Territories', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guinea', 'Guinea-bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Korea (North)', 'Korea (South)', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macau', 'Macedonia', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia', 'Moldova', 'Monaco', 'Mongolia', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'Netherlands Antilles', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island', 'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Kitts And Nevis', 'Saint Lucia', 'St Vincent/Grenadines', 'Samoa', 'San Marino', 'Sao Tome', 'Saudi Arabia', 'Senegal', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'Spain', 'Sri Lanka', 'St. Helena', 'St.Pierre', 'Sudan', 'Suriname', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tokelau', 'Tonga', 'Trinidad And Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican City State', 'Venezuela', 'Viet Nam', 'Virgin Islands (British)', 'Virgin Islands (U.S.)', 'Western Sahara', 'Yemen', 'Yugoslavia', 'Zaire', 'Zambia', 'Zimbabwe']

# %%
# Next step: find out geo-distribution of users
# Find where tweets come from according to their users' location
from geopy.geocoders import Nominatim
for i in country:
    geolocator = Nominatim()
    location = geolocator.geocode(country)
    print((location.latitude, location.longitude))
location.address
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-2f5f2d36a67f> in <module>
#       5     geolocator = Nominatim()
#       6     location = geolocator.geocode(country)
# ----> 7     print((location.latitude, location.longitude))
#       8 location.address
#
# AttributeError: 'NoneType' object has no attribute 'latitude'
